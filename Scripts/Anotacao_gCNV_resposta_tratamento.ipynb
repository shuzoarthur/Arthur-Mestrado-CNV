# %% [markdown]
# <a href="https://colab.research.google.com/github/shuzoarthur/Mestrado/blob/main/Scripts/Anotacao_gCNV_resposta_tratamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
anotacao_gcnv_df = pd.read_excel('/content/drive/MyDrive/Arthur Mestrado/Resultados Mestrado/Anotacao_CNV/ClassifyGermilineCNV by Segments.xlsx', sheet_name='Sheet1')
# Rename column 'ID Biobanco' to 'Nº Biobanco'
anotacao_gcnv_df.rename(columns={'ID Biobanco': 'Nº Biobanco'}, inplace=True)

# %%
resposta_df = pd.read_csv('/content/drive/MyDrive/Arthur Mestrado/Resultados Mestrado/RetratosDaMama-Arthur_DATA_LABELS_2025-05-05_1243.csv', delimiter=';')

# %%
# Merge 'anotacao_gcnv_df' with 'resposta_df' by column 'Nº Biobanco'
merged_df = pd.merge(anotacao_gcnv_df, resposta_df, on='Nº Biobanco')

# %%
# Download 'merged_df' as .csv file
merged_df.to_csv('annotation_treatment_merged_df.csv', index=False)

# %%
resposta_df.head()
# Out:
#    ID do paciente  Repeat Instrument  Repeat Instance  Nº Biobanco  \
# 0            4137                NaN              NaN         5001
# 1            5068                NaN              NaN         5023
# 2            6042                NaN              NaN         3828
# 3            6062                NaN              NaN         3829
# 4            6157                NaN              NaN         3833
#
#    Idade (inicio do estudo) Raça declarada   IMC  \
# 0                        38          Parda  29.0
# 1                        37            NaN  43.0
# 2                        39          Parda  36.0
# 3                        28         Branca  42.0
# 4                        36          Parda  27.0
#
#   Possui histórico familiar de câncer? Hábito de fumar  \
# 0                                  Não     nunca fumou
# 1                                  Sim     nunca fumou
# 2                                  Sim     nunca fumou
# ...

# %%
anotacao_gcnv_df.head()
# Out:
#       Sample Nº Biobanco                     VariantID Chromosome      Start  \
# 0   Sample 0       10407    chr6_33446325_33456772_DEL       chr6   33446325
# 1   Sample 1       10410    chr6_31622540_31997102_DEL       chr6   31622540
# 2   Sample 1       10410    chr6_33435411_33456772_DEL       chr6   33435411
# 3   Sample 1       10410  chr9_134641938_134642546_DEL       chr9  134641938
# 4  Sample 10        7604   chr15_82539731_82540678_DEL      chr15   82539731
#
#          End Type     Classification  Total score  1A-B  ...  5A  5B  5C  5D  \
# 0   33456772  DEL  Likely pathogenic          0.9     0  ...   0   0   0   0
# 1   31997102  DEL  Likely pathogenic          0.9     0  ...   0   0   0   0
# 2   33456772  DEL  Likely pathogenic          0.9     0  ...   0   0   0   0
# 3  134642546  DEL  Likely pathogenic          0.9     0  ...   0   0   0   0
# 4   82540678  DEL  Likely pathogenic          0.9     0  ...   0   0   0   0
#
# ...
